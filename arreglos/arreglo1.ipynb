# %%
vector = []
vector.append(8)
vector.append(9)
vector.append(11)
print(vector)
print(vector[0])
print(vector[1])
print(vector[2])
print(vector[-1])
print(vector[-2])
print(vector[-3])
# Out:
# [8, 9, 11]
# 8
# 9
# 11
# 11
# 9
# 8

# %%
vector2 = [2018, 9.12, "Michael"]
print(vector2)
# Out:
# [2018, 9.12, 'Michael']

# %%
vector2.insert(1, "Managua")
print(vector2)
# Out:
# [2018, 'Managua', 9.12, 'Michael']

# %%
#Recorrer el vector
for item in vector2:
    print(item)
# Out:
# 2018
# Managua
# 9.12
# Michael

# %%
for i in range(4):
    print(vector2[i])
# Out:
# 2018
# Managua
# 9.12
# Michael
